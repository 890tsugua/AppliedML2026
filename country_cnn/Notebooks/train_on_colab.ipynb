# %%
# !git clone https://github.com/890tsugua/AppliedML2026.git
# %cd AppliedML2026
# !ls
# Out:
# Cloning into 'AppliedML2026'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 174 (delta 18), reused 31 (delta 7), pack-reused 131 (from 1)
# Receiving objects: 100% (174/174), 77.71 MiB | 25.63 MiB/s, done.
# Resolving deltas: 100% (92/92), done.
# /content/AppliedML2026
# country_cnn  README.md

# %%
# Mount to the folder in google drive
from google.colab import drive
from pathlib import Path

drive.mount("/content/drive")

data_dir = Path("/content/drive/MyDrive/AppliedMLdata2026")

print(data_dir.exists())
print(list(data_dir.iterdir())[:5])
# Out:
# Mounted at /content/drive
# True
# [PosixPath('/content/drive/MyDrive/AppliedMLdata2026/train_data'), PosixPath('/content/drive/MyDrive/AppliedMLdata2026/test_data'), PosixPath('/content/drive/MyDrive/AppliedMLdata2026/AppliedMLdata2026.zip')]
